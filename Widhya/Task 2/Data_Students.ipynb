# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import numpy as np
from pandas import Series, DataFrame
# %matplotlib notebook

# %%
#create an empty dictionary as we need to store key/value pairs
itemDic = {}
    # where fileName is the name of the csv file
    #first we must open the csv file and read it
import csv
with open("Dataset - Data Science Task - User-Feedback.csv", "r") as itemFile:
    #we are using itemFile as the handle
    csvReader = csv.reader(itemFile, delimiter=",", quotechar='"')
        #skip the header because we don't need to do anything with it
    next(csvReader)
        #now that we have skipped the header we need to iterate through the rows
    for row in csvReader:
            #troubleshooting diagnostic, for loop:
            #print(row)
            #now we need to take the second column entry of the csv and assign that as the key
            #and the total number of its instances as the value to that key
            #quite frankly I have no idea how to do that.
        if row[23] not in itemDic:
            itemDic[row[23]] = 1
        else:
            itemDic[row[23]] += 1
        #print the new dictionary
    print (itemDic)
# Out:
# {'Deep Learning': 2, 'Visualization ': 1, 'Graphic design': 1, 'Mainly data preprocessing and feature engineering part': 1, 'Computer Vision': 1, 'NLP': 3, 'Web Development ': 1, 'Neural networks': 1, 'NLP hands-on, Deep learning-computer vision hands-on': 1, 'end to end complete ML project': 1, 'Full Stack data science projects': 1, 'Data visualisation can be covered': 1, 'CyberSecurity,BlockChain': 1, 'App development': 1, 'They are just fine.': 1, 'Ui UX designing ': 1, 'Statistics, Data Visualization (Power BI or Tableau or both), Advanced Excel, Same mission on R (for those who are comfortable in R), and SQL': 1, 'Different algorithms to be applied on the datasets': 1, 'Big Data and clouding computing are my recommendations which i would like widhya to cover in missions': 1, 'Interactive Data visualizations': 1, 'Unsupervised Learning': 1, 'More concepts like Forecasting, Time Series, Market Basket Analysis and Recommendation System could be covered in the further missions.': 2,
# ...

# %%
li_keys = []
for key in itemDic.keys():
    li_keys.append(key)

# %%
li_values = []
for value in itemDic.values():
    li_values.append(value)

# %%
df2 = pd.DataFrame((zip(li_keys, li_values)), 
               columns =['Name', 'val'])

# %%
deep_learning_list = ['Deep Learning', 'deep learning', 'deep Learning']
deep_learning_count = 0
data_visualisation_list = ['Visualisation','Visualization','visualisation','visualization''Data Visualisation','Data Visualization','data visualisation','data visualization','data visualizations']
data_visualisation_count = 0
nlp_list = ['NLP','nlp','Nlp','Natural Language Processing']
nlp_count = 0
web_development_list = ['Web development','web development','Web Development']
web_development_count = 0
neural_networks_list = ['NN','nn','Nn','Neural Networks','Neural networks','neural networks']
neural_networks_count = 0
graphic_design_list = ['Graphic Design','Graphic design', 'graphic design']
graphic_design_count = 0
data_preprocessing_list = ['Data Preprocessing','Data preprocessing','data preprocessing']
data_preprocessing_count = 0
machine_learning_list = ['ML','Ml','ml','Machine Learning','Machine learning','machine learning']
machine_learning_count = 0
cyber_security_list = ['CyberSecurity','Cyber security','cyber security']
cyber_security_count = 0
blockchain_list = ['Blockchain','blockchain']
blockchain_count = 0
app_development_list = ['App Development','app development','App development']
app_development_count = 0
ux_design_list = ['UX','ux','UI','ui','Ux','Ui']
ux_design_count = 0
statistics_list = ['Statistics','statistics']
statistics_count = 0
big_data_list = ['Big Data','Big data','big data']
big_data_count = 0
cloud_computing_list = ['Cloud','cloud']
cloud_computing_count = 0
sql_list = ['SQL','sql']
sql_count = 0
django_list = ['Django','django']
django_count = 0
artificial_intelligence_list = ['AI','Artificial Intelligence','artificial intelligence','Artificial intelligence']
artificial_intelligence_count = 0
flutter_list = ['Flutter','flutter']
flutter_count = 0
javascript_list = ['Javascript','javascript','JS','js']
javascript_count = 0

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in deep_learning_list):
        deep_learning_count += pd.to_numeric(df2['val'][i])
deep_learning_count
# Out:
# 4

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in data_visualisation_list):
        data_visualisation_count += pd.to_numeric(df2['val'][i])
data_visualisation_count
# Out:
# 4

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in nlp_list):
        nlp_count += pd.to_numeric(df2['val'][i])
nlp_count
# Out:
# 5

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in web_development_list):
        web_development_count += pd.to_numeric(df2['val'][i])
web_development_count
# Out:
# 1

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in neural_networks_list):
        neural_networks_count += pd.to_numeric(df2['val'][i])
neural_networks_count
# Out:
# 3

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in graphic_design_list):
        graphic_design_count += pd.to_numeric(df2['val'][i])
graphic_design_count
# Out:
# 1

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in data_preprocessing_list):
        data_preprocessing_count += pd.to_numeric(df2['val'][i])
data_preprocessing_count
# Out:
# 1

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in machine_learning_list):
        machine_learning_count += pd.to_numeric(df2['val'][i])
machine_learning_count
# Out:
# 3

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in cyber_security_list):
        cyber_security_count += pd.to_numeric(df2['val'][i])
cyber_security_count
# Out:
# 2

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in blockchain_list):
        blockchain_count += pd.to_numeric(df2['val'][i])
blockchain_count
# Out:
# 1

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in app_development_list):
        app_development_count += pd.to_numeric(df2['val'][i])
app_development_count
# Out:
# 1

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in ux_design_list):
        ux_design_count += pd.to_numeric(df2['val'][i])
ux_design_count
# Out:
# 1

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in statistics_list):
        statistics_count += pd.to_numeric(df2['val'][i])
statistics_count
# Out:
# 1

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in big_data_list):
        big_data_count += pd.to_numeric(df2['val'][i])
big_data_count
# Out:
# 1

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in cloud_computing_list):
        cloud_computing_count += pd.to_numeric(df2['val'][i])
cloud_computing_count
# Out:
# 5

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in sql_list):
        sql_count += pd.to_numeric(df2['val'][i])
sql_count
# Out:
# 1

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in django_list):
        django_count += pd.to_numeric(df2['val'][i])
django_count
# Out:
# 4

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in artificial_intelligence_list):
        artificial_intelligence_count += pd.to_numeric(df2['val'][i])
artificial_intelligence_count
# Out:
# 4

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in flutter_list):
        flutter_count += pd.to_numeric(df2['val'][i])
flutter_count
# Out:
# 6

# %%
for i,row in enumerate(df2['Name']):
    if any(x in row for x in javascript_list):
        javascript_count += pd.to_numeric(df2['val'][i])
javascript_count
# Out:
# 2

# %%
dict1 = {'Deep Learning':deep_learning_count,
         'Data Visualisation':data_visualisation_count,
         'Natural Language Processing':nlp_count,
         'Web Development':web_development_count,
         'Neural Network':neural_networks_count,
         'Graphic Design':graphic_design_count,
         'Data Preprocessing':data_preprocessing_count,
         'Machine Learning':machine_learning_count,
         'Cyber Security':cyber_security_count,
         'Blockchain':blockchain_count,
         'App Development':app_development_count,
         'UX/UI Design':ux_design_count,
         'Statistics':statistics_count,
         'Big Data':big_data_count,
         'Cloud Computing':cloud_computing_count,
         'SQL':sql_count,
         'Django':django_count,
         'Artificial Intelligence':artificial_intelligence_count,
         'Flutter':flutter_count,
         'Javascript':javascript_count}

# %%
df3 = pd.Series(dict1,index=dict1.keys())

# %%
df3.plot.bar() 
plt.savefig('plot.png', dpi=500, bbox_inches='tight')

# %%
df = pd.read_csv('Dataset - Data Science Task - User-Feedback.csv')

# %%
df
# Out:
#    How would you categorise yourself in college? (This in no way will determine your selection. It is just for us to get a better understanding of your academic performance if you think it is necessary for us to know)  \
# 0                                     Top 5% in class
# 1                                     Top 2% in class
# 2                                     Top 2% in class
# 3                                    Top 10% in class
# 4                                    Top 10% in class
# 5                                                 NaN
# 6                                    Top 10% in class
# 7                                    Top 25% in class
# 8                                    Top 25% in class
# 9                                    Top 10% in class
# 10                                   Top 25% in class
# 11                                              Other
# 12                                              Other
# ...

# %%
df.describe()
# Out:
#        How much would you rate the look of the platform on a scale of 1-10 where 1 is the least rating while 10 is the highest ?  \
# count                                          75.000000
# mean                                            8.186667
# std                                             1.259487
# min                                             4.000000
# 25%                                             7.000000
# 50%                                             8.000000
# 75%                                             9.000000
# max                                            10.000000
#
#        On a scale of 1-10, how effective was the "Widhya way of learning" for you?  \
# count                                          75.000000
# mean                                            8.613333
# std                                             1.161236
# min                                             5.000000
# 25%                                             8.000000
# ...

# %%
df3.to_csv(index=False)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
# '4\r\n4\r\n5\r\n1\r\n3\r\n1\r\n1\r\n3\r\n2\r\n1\r\n1\r\n1\r\n1\r\n1\r\n5\r\n1\r\n4\r\n4\r\n6\r\n2\r\n'
